# %%
# !pip install snowflake-connector-python snowflake-ingest python-dotenv
# Out:
# Requirement already satisfied: snowflake-connector-python in c:\users\ramik\anaconda3\lib\site-packages (3.14.0)
# Collecting snowflake-ingest
#   Downloading snowflake_ingest-1.0.10-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (1.17.1)
# Requirement already satisfied: cryptography>=3.1.0 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (43.0.0)
# Requirement already satisfied: pyOpenSSL<26.0.0,>=22.0.0 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (24.2.1)
# Requirement already satisfied: pyjwt<3.0.0 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (2.8.0)
# Requirement already satisfied: pytz in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (2024.1)
# Requirement already satisfied: requests<3.0.0 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (2.32.3)
# Requirement already satisfied: packaging in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (24.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (2024.8.30)
# Requirement already satisfied: typing_extensions<5,>=4.3 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (4.11.0)
# Requirement already satisfied: filelock<4,>=3.5 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (3.13.1)
# Requirement already satisfied: sortedcontainers>=2.4.0 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (3.10.0)
# Requirement already satisfied: tomlkit in c:\users\ramik\anaconda3\lib\site-packages (from snowflake-connector-python) (0.11.1)
# Collecting furl (from snowflake-ingest)
#   Downloading furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pycparser in c:\users\ramik\anaconda3\lib\site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python) (2.21)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ramik\anaconda3\lib\site-packages (from requests<3.0.0->snowflake-connector-python) (2.2.3)
# Requirement already satisfied: six>=1.8.0 in c:\users\ramik\anaconda3\lib\site-packages (from furl->snowflake-ingest) (1.16.0)
# Collecting orderedmultidict>=1.0.1 (from furl->snowflake-ingest)
#   Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading snowflake_ingest-1.0.10-py3-none-any.whl (15 kB)
# Downloading furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Downloading orderedmultidict-1.0.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: orderedmultidict, furl, snowflake-ingest
# Successfully installed furl-2.1.4 orderedmultidict-1.0.1 snowflake-ingest-1.0.10

# %%
import snowflake.connector
import random
import json
import os
from decimal import Decimal
from dotenv import load_dotenv
# Load environment variables from .env (if present)
load_dotenv()

# Connect to Snowflake using environment variables (set in env or CI)
# Required env vars: SNOW_USER, SNOW_PASSWORD, SNOW_ACCOUNT
# Optional: SNOW_WAREHOUSE, SNOW_DATABASE, SNOW_SCHEMA
conn = snowflake.connector.connect(
    user=os.getenv('SNOW_USER'),
    password=os.getenv('SNOW_PASSWORD'),
    account=os.getenv('SNOW_ACCOUNT'),
    warehouse=os.getenv('SNOW_WAREHOUSE', 'COMPUTE_WH'),
    database=os.getenv('SNOW_DATABASE', 'TEST1'),
    schema=os.getenv('SNOW_SCHEMA', 'STREAM')
)

cursor = conn.cursor()

def get_existing_patient_ids():
    """Fetch existing PATIENTID values from the Snowflake table."""
    cursor.execute("SELECT PATIENTID FROM TEST1")
    return {row[0] for row in cursor.fetchall()}

def generate_decimal(min_val, max_val, precision=15):
    """Generate a decimal number with the specified precision."""
    return round(random.uniform(min_val, max_val), precision)

def generate_patient_data(num_records=50):
    existing_ids = get_existing_patient_ids()
    records = []
    doctor_name = "DrXXXConfid"
    
    while len(records) < num_records:
        patient_id = random.randint(1000, 3000) if random.choice([True, False]) else random.randint(5200, 9999)
        if patient_id in existing_ids:
            continue  # Avoid duplicate patient IDs
        
        record = {
            'PATIENTID': patient_id,
            'AGE': random.randint(50, 90),
            'GENDER': random.randint(0, 1),
            'ETHNICITY': random.randint(0, 3),
            'EDUCATIONLEVEL': random.randint(0, 3),
            'BMI': generate_decimal(15, 40),
            'SMOKING': random.randint(0, 1),
            'ALCOHOLCONSUMPTION': generate_decimal(0, 20, 19),
            'PHYSICALACTIVITY': generate_decimal(0, 10, 18),
            'DIETQUALITY': generate_decimal(0, 10, 18),
            'SLEEPQUALITY': generate_decimal(4, 10, 16),
            'FAMILYHISTORYPARKINSONS': random.randint(0, 1),
            'TRAUMATICBRAININJURY': random.randint(0, 1),
            'HYPERTENSION': random.randint(0, 1),
            'DIABETES': random.randint(0, 1),
            'DEPRESSION': random.randint(0, 1),
            'STROKE': random.randint(0, 1),
            'SYSTOLICBP': random.randint(90, 180),
            'DIASTOLICBP': random.randint(60, 120),
            'CHOLESTEROLTOTAL': generate_decimal(150, 300, 14),
            'CHOLESTEROLLDL': generate_decimal(50, 200, 15),
            'CHOLESTEROLHDL': generate_decimal(20, 100, 15),
            'CHOLESTEROLTRIGLYCERIDES': generate_decimal(50, 400, 15),
            'UPDRS': generate_decimal(0, 199, 18),
            'MOCA': generate_decimal(0, 30, 18),
            'FUNCTIONALASSESSMENT': generate_decimal(0, 10, 18),
            'TREMOR': random.randint(0, 1),
            'RIGIDITY': random.randint(0, 1),
            'BRADYKINESIA': random.randint(0, 1),
            'POSTURALINSTABILITY': random.randint(0, 1),
            'SPEECHPROBLEMS': random.randint(0, 1),
            'SLEEPDISORDERS': random.randint(0, 1),
            'CONSTIPATION': random.randint(0, 1),
            'DIAGNOSIS': random.randint(0, 1),
            'DOCTORINCHARGE': doctor_name
        }
        records.append(record)
    
    return records

try:
    records = generate_patient_data(50)
    json_file = "patient_data.json"
    
    with open(json_file, "w") as f:
        for record in records:
            json.dump(record, f)
            f.write("\n")
    
    cursor.execute("CREATE TEMPORARY STAGE IF NOT EXISTS temp_stage")
    cursor.execute(f"PUT file://{json_file} @temp_stage")
    
    cursor.execute("""
    COPY INTO TEST1
    FROM @temp_stage/patient_data.json.gz
    FILE_FORMAT = (TYPE = 'JSON')
    MATCH_BY_COLUMN_NAME = CASE_INSENSITIVE
    """)
    
    print(f"Successfully loaded {len(records)} records into TEST1")
except Exception as e:
    print(f"Error loading data: {e}")
finally:
    try:
        cursor.execute("DROP STAGE IF EXISTS temp_stage")
        os.remove(json_file)
    except Exception as e:
        print(f"Error during cleanup: {e}")
    cursor.close()
    conn.close()
    print("Connections closed")
# Out:
# Successfully loaded 50 records into TEST1
# Connections closed
